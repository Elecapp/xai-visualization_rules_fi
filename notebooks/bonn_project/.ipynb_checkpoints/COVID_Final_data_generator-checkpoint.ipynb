# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OrdinalEncoder, FunctionTransformer, LabelEncoder
#from sklearn import metrics 
from xailib.data_loaders.dataframe_loader import prepare_dataframe

 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
 
from sklearn.compose import make_column_selector as selector

from lore_sa.dataset import TabularDataset
from lore_sa.surrogate import DecisionTreeSurrogate

import matplotlib.pyplot as plt
# Out:
# 2024-05-24 13:52:21,592 matplotlib   DEBUG    matplotlib data path: /opt/anaconda3/envs/xai/lib/python3.8/site-packages/matplotlib/mpl-data
# 2024-05-24 13:52:21,600 matplotlib   DEBUG    CONFIGDIR=/Users/eleonoracappuccio/.matplotlib
# 2024-05-24 13:52:21,603 matplotlib   DEBUG    interactive is False
# 2024-05-24 13:52:21,604 matplotlib   DEBUG    platform is darwin
# 2024-05-24 13:52:21,680 matplotlib   DEBUG    CACHEDIR=/Users/eleonoracappuccio/.matplotlib
# 2024-05-24 13:52:21,684 matplotlib.font_manager DEBUG    Using fontManager instance from /Users/eleonoracappuccio/.matplotlib/fontlist-v330.json

# %%
df = pd.read_csv("../../datasets/Final_data.csv")
 
df = df.loc[:,['Class_label','Week5_Covid', 'Week4_Covid', 'Week3_Covid', 'Week5_Mobility','Week4_Mobility','Week3_Mobility','Week2_Mobility', 'Days_passed', 'Duration']]
 
mask = df.drop(["Class_label"], axis=1).isna().all(axis=1) & df['Class_label'].notna()
result_df = df[~mask]
#df = df.dropna(how = 'all')
result_df = result_df.fillna("NONE")

# %%
result_df.head()
# Out:
#   Class_label Week5_Covid Week4_Covid Week3_Covid Week5_Mobility  \
# 0          c1          c4          c4          c3             m1
# 1          c2          c4          c4          c4             m4
# 2          c2          c1          c1          c1             m3
# 3          c3          c2          c3          c4             m4
# 4          c3          c1          c1          c1             m3
#
#   Week4_Mobility Week3_Mobility Week2_Mobility  Days_passed  Duration
# 0             m1             m1             m1         63.0        84
# 1             m1             m1             m1         56.0         7
# 2             m3             m3             m3        147.0        14
# 3             m4             m4             m1         42.0        14
# 4             m3             m3             m3        161.0        14

# %%
y = result_df["Class_label"].values
X_feat = result_df.loc[:,'Week5_Covid':'Duration']

# %%
numerical_columns_selector = selector(dtype_exclude=object)
categorical_columns_selector = selector(dtype_include=object)

# %%
numerical_columns = numerical_columns_selector(X_feat)
categorical_columns = categorical_columns_selector(X_feat)

# %%
covid_categories = ['NONE', 'c1', 'c2', 'c3', 'c4']
mobility_categories = ['NONE','m1', 'm2', 'm3', 'm4']
 
enc = OrdinalEncoder(categories=[covid_categories,covid_categories,covid_categories, mobility_categories,mobility_categories,mobility_categories,mobility_categories])
numerical_preprocessor = StandardScaler()

# %%
preprocessor = ColumnTransformer(
    [
        ("ordinal-encoder", enc, categorical_columns),
        ("standard_scaler", numerical_preprocessor, numerical_columns),
    ]
)

# %%
clf = RandomForestClassifier(n_estimators = 100, random_state=0)
model = make_pipeline(preprocessor, clf)
 
#y_prediction = cross_val_predict(model, X_feat,y, cv=5)
#acc = cross_val_score(model, X_feat,y, cv=5)

# %%
data_train, data_test, target_train, target_test = train_test_split(
    X_feat, y, random_state=0
)

# %%
data_train
# Out:
#     Week5_Covid Week4_Covid Week3_Covid Week5_Mobility Week4_Mobility  \
# 255          c1          c1          c2             m4             m4
# 229          c3          c3          c3             m3             m2
# 300          c3          c3          c3             m2             m3
# 7            c3          c4          c4             m2             m3
# 160          c1          c1          c2             m4             m4
# ..          ...         ...         ...            ...            ...
# 323          c3          c3          c3             m3             m3
# 192          c1          c1          c1             m4             m4
# 117          c3          c4          c4             m3             m4
# 47           c3          c4          c4             m3             m4
# 172          c1          c2          c2             m3             m3
#
#     Week3_Mobility Week2_Mobility  Days_passed  Duration
# 255             m4             m1         42.0         7
# 229             m3             m3        322.0        35
# 300             m2             m2        329.0        21
# 7               m3             m3        357.0        49
# 160             m4             m1         42.0        21
# ..             ...            ...          ...       ...
# 323             m3             m4        224.0        63
# 192             m4             m4        182.0        42
# 117             m4             m4        273.0        28
# 47              m4             m3        273.0        21
# 172             m3             m3        168.0        28
#
# [351 rows x 9 columns]

# %%
_ = model.fit(data_train, target_train)
 
y_predict = model.predict(data_test)
 
print(model.score(data_test, target_test))
# Out:
# 0.8888888888888888

# %%
predictions = model.predict(data_test)
cm = confusion_matrix(target_test, predictions, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()
plt.show()
# Out:
# 2024-05-24 13:53:02,093 matplotlib.colorbar DEBUG    locator: <matplotlib.ticker.AutoLocator object at 0x7fa3fb243fa0>

# %% [markdown]
# # Neighborhood generation

# %%
generator_ordinal=data_train.loc[:,'Week5_Covid':'Week2_Mobility']
generator_ordinal= enc.fit_transform(generator_ordinal)

# %%
generator_preprocessor = ColumnTransformer(
    transformers = [
        ("ordinal-encoder", enc, categorical_columns),
    ],
    remainder='passthrough'
)

# %%
generator_data = generator_preprocessor.fit_transform(data_train)

# %%
generator_data
# Out:
# array([[  1.,   1.,   2., ...,   1.,  42.,   7.],
#        [  3.,   3.,   3., ...,   3., 322.,  35.],
#        [  3.,   3.,   3., ...,   2., 329.,  21.],
#        ...,
#        [  3.,   4.,   4., ...,   4., 273.,  28.],
#        [  3.,   4.,   4., ...,   3., 273.,  21.],
#        [  1.,   2.,   2., ...,   3., 168.,  28.]])

# %%
generator_data[95]
# Out:
# array([  3.,   3.,   3.,   3.,   3.,   3.,   3., 413.,  28.])

# %% [markdown]
# ### Generator

# %%
import random
class NewGenElegant:
    def __init__(self):
        self.gen_data = None
 
    def perturb(self, x, num_instances):
        perturbed_arrays = []

        choices = [0, 1, 2, 3, 4]
        
        covid_weights = [
            [0.0, 0.25, 0.13, 0.36, 0.26], #0
            [0.0, 0.40, 0.30, 0.20, 0.10], #1
            [0.0, 0.25, 0.40, 0.25, 0.10], #2
            [0.0, 0.10, 0.25, 0.40, 0.25], #3
            [0.0, 0.10, 0.20, 0.30, 0.40], #4
        ]

        mobility_weights=[
            [0.0, 0.12, 0.18, 0.45, 0.24], #0
            [0.0, 0.40, 0.30, 0.20, 0.10], #1
            [0.0, 0.25, 0.40, 0.25, 0.10],#2
            [0.0, 0.10, 0.25, 0.40, 0.25], #3
            [0.0, 0.10, 0.20, 0.30, 0.40] #4
        
        ]

        for _ in range(num_instances):
            perturbed_arr = x[:]
    
            for val in range(0,3): #covid
                perturbed_arr[val] = random.choices(choices, weights = covid_weights[val])[0]
                
            for val in range(3, 7): #mobility
                perturbed_arr[val] = random.choices(choices, weights = mobility_weights[val-3])[0]
                    
            perturbed_arr[7]= random.choice(range(42, 442, 7)) 
            perturbed_arr[8]= random.choice(range(7, 148, 7))
                 
            perturbed_arrays.append(perturbed_arr)
        self.gen_data = perturbed_arrays
        return perturbed_arrays
 
 
# Example usage:
 
 
x =list(generator_data[5])
perturber = NewGenElegant()
n = 100
perturbed_arrays = perturber.perturb(x=x, num_instances=n)
for perturbed_arr in perturbed_arrays:
    print(perturbed_arr)
# Out:
# [2, 1, 3, 4, 2, 4, 3, 161, 63]
# [3, 4, 4, 3, 2, 3, 3, 119, 21]
# [3, 1, 1, 3, 4, 4, 1, 350, 28]
# [4, 3, 1, 1, 4, 2, 3, 105, 49]
# [1, 2, 4, 3, 2, 2, 2, 182, 105]
# [3, 2, 1, 1, 2, 3, 3, 315, 63]
# [4, 1, 2, 3, 1, 2, 4, 399, 126]
# [3, 1, 3, 3, 2, 2, 4, 105, 126]
# [1, 1, 1, 3, 2, 1, 3, 105, 119]
# [3, 1, 3, 2, 2, 3, 2, 175, 84]
# [4, 4, 2, 1, 2, 2, 3, 231, 133]
# [3, 2, 2, 3, 2, 4, 2, 140, 70]
# [2, 2, 1, 3, 4, 3, 2, 231, 21]
# [4, 1, 3, 4, 2, 2, 2, 434, 49]
# [4, 1, 3, 3, 1, 2, 4, 189, 56]
# [1, 1, 2, 3, 4, 3, 2, 154, 77]
# [4, 4, 1, 1, 3, 1, 4, 210, 77]
# [3, 1, 2, 3, 1, 1, 3, 350, 84]
# [3, 4, 1, 1, 1, 2, 4, 427, 63]
# [2, 2, 4, 2, 1, 3, 2, 217, 147]
# [3, 2, 1, 3, 2, 2, 4, 301, 14]
# [3, 2, 4, 3, 3, 2, 3, 329, 35]
# [4, 2, 2, 3, 1, 4, 4, 217, 126]
# [3, 2, 3, 4, 3, 2, 3, 427, 70]
# [4, 1, 1, 3, 1, 2, 4, 322, 63]
# [1, 1, 1, 3, 2, 2, 3, 301, 42]
# [3, 1, 2, 3, 2, 2, 2, 119, 42]
# [1, 3, 2, 1, 1, 2, 4, 119, 7]
# [3, 2, 1, 4, 3, 2, 3, 287, 112]
# [3, 1, 1, 2, 4, 3, 3, 273, 147]
# [3, 2, 2, 1, 3, 2, 3, 378, 70]
# [4, 3, 3, 4, 4, 2, 2, 203, 84]
# [1, 1, 2, 2, 3, 1, 3, 385, 112]
# [3, 1, 2, 2, 4, 3, 2, 210, 42]
# [1, 1, 4, 4, 1, 3, 3, 98, 35]
# [3, 2, 1, 2, 2, 2, 3, 63, 21]
# [3, 1, 2, 2, 2, 2, 3, 49, 98]
# [4, 1, 4, 2, 1, 2, 3, 147, 56]
# [4, 2, 3, 3, 4, 2, 3, 161, 84]
# [4, 3, 1, 4, 2, 2, 4, 231, 105]
# [4, 1, 1, 4, 1, 2, 1, 238, 140]
# [3, 2, 3, 2, 2, 2, 3, 287, 7]
# [4, 3, 2, 3, 2, 1, 3, 70, 28]
# [1, 1, 1, 3, 2, 3, 1, 126, 28]
# [3, 3, 3, 3, 4, 3, 4, 308, 105]
# [3, 1, 2, 3, 1, 1, 3, 301, 140]
# [3, 4, 1, 4, 2, 4, 1, 322, 84]
# [4, 1, 4, 3, 4, 3, 1, 357, 21]
# [4, 1, 2, 2, 2, 2, 3, 189, 49]
# [4, 2, 1, 4, 1, 3, 2, 343, 35]
# [2, 4, 1, 2, 4, 2, 4, 133, 77]
# [3, 3, 2, 3, 1, 1, 3, 378, 7]
# [1, 3, 4, 2, 1, 2, 3, 336, 147]
# [1, 3, 2, 2, 1, 1, 2, 189, 91]
# [2, 4, 2, 2, 4, 2, 3, 329, 21]
# [4, 2, 2, 4, 3, 4, 1, 203, 21]
# [1, 1, 1, 3, 3, 2, 3, 343, 98]
# [2, 2, 2, 3, 3, 2, 4, 287, 77]
# [2, 1, 2, 4, 1, 3, 2, 315, 126]
# [1, 1, 4, 3, 3, 2, 2, 154, 7]
# [1, 2, 2, 3, 1, 3, 3, 56, 98]
# [2, 4, 1, 4, 1, 1, 4, 147, 56]
# [4, 2, 2, 2, 3, 2, 3, 413, 49]
# [1, 2, 3, 3, 3, 3, 4, 196, 140]
# [1, 2, 1, 3, 2, 2, 2, 315, 147]
# [3, 3, 2, 3, 1, 2, 2, 56, 119]
# [2, 3, 2, 1, 2, 2, 4, 112, 133]
# [1, 2, 1, 3, 1, 2, 2, 147, 98]
# [3, 1, 4, 3, 2, 1, 4, 259, 56]
# [4, 1, 2, 1, 1, 3, 4, 182, 14]
# [3, 1, 3, 3, 1, 2, 4, 231, 77]
# [1, 1, 4, 2, 4, 1, 3, 175, 7]
# [1, 1, 4, 3, 2, 2, 4, 392, 105]
# [2, 2, 3, 3, 1, 3, 2, 343, 35]
# [4, 3, 2, 3, 1, 2, 2, 84, 63]
# [3, 1, 3, 3, 1, 2, 2, 378, 112]
# [2, 2, 3, 3, 3, 1, 4, 420, 21]
# [1, 1, 2, 4, 4, 1, 1, 392, 147]
# [4, 1, 4, 4, 1, 3, 1, 175, 28]
# [1, 1, 3, 4, 2, 1, 4, 252, 105]
# [2, 2, 2, 3, 4, 1, 3, 301, 98]
# [2, 2, 3, 3, 3, 1, 3, 441, 28]
# [3, 1, 1, 4, 1, 1, 2, 315, 147]
# [1, 2, 1, 1, 1, 2, 2, 322, 77]
# [1, 1, 2, 2, 4, 1, 2, 175, 105]
# [3, 1, 2, 4, 3, 2, 3, 434, 133]
# [1, 2, 2, 3, 2, 2, 4, 119, 140]
# [4, 3, 1, 3, 2, 1, 2, 238, 98]
# [1, 2, 1, 3, 3, 1, 3, 266, 42]
# [1, 1, 2, 1, 1, 3, 2, 357, 70]
# [1, 1, 1, 3, 2, 1, 2, 322, 105]
# [1, 2, 2, 3, 2, 3, 2, 420, 133]
# [3, 4, 3, 3, 1, 1, 4, 63, 28]
# [3, 2, 4, 4, 2, 3, 4, 182, 49]
# [1, 4, 1, 3, 1, 3, 2, 252, 105]
# [4, 2, 2, 4, 1, 4, 2, 91, 42]
# [3, 3, 2, 2, 1, 2, 2, 77, 105]
# [1, 1, 4, 4, 3, 2, 4, 49, 7]
# [2, 4, 3, 3, 3, 4, 2, 406, 63]
# [1, 1, 3, 2, 1, 3, 4, 378, 126]

# %%
columns=X_feat.columns

# %%
columns
# Out:
# Index(['Week5_Covid', 'Week4_Covid', 'Week3_Covid', 'Week5_Mobility',
#        'Week4_Mobility', 'Week3_Mobility', 'Week2_Mobility', 'Days_passed',
#        'Duration'],
#       dtype='object')

# %%
neighbour_df_5 = pd.DataFrame(perturbed_arrays, columns=columns)
neighbour_df_5.head()
# Out:
#    Week5_Covid  Week4_Covid  Week3_Covid  Week5_Mobility  Week4_Mobility  \
# 0            2            1            3               4               2
# 1            3            4            4               3               2
# 2            3            1            1               3               4
# 3            4            3            1               1               4
# 4            1            2            4               3               2
#
#    Week3_Mobility  Week2_Mobility  Days_passed  Duration
# 0               4               3          161        63
# 1               3               3          119        21
# 2               4               1          350        28
# 3               2               3          105        49
# 4               2               2          182       105

# %% [markdown]
# We now use the black box we created before to classify all the instances of the new synthetic dataset

# %%
neighbour_df_5.to_csv('../../datasets/neighbourhood_5.csv', index=False)  
neighbour=TabularDataset.from_csv('../../datasets/neighbourhood_5.csv')
# Out:
# 2024-05-24 13:52:23,421 root         WARNING  No target class is defined
# 2024-05-24 13:52:23,421 root         INFO     ../../datasets/neighbourhood_5.csv file imported

# %%
neighbour.df
# Out:
#     Week5_Covid  Week4_Covid  Week3_Covid  Week5_Mobility  Week4_Mobility  \
# 0             2            1            3               4               2
# 1             3            4            4               3               2
# 2             3            1            1               3               4
# 3             4            3            1               1               4
# 4             1            2            4               3               2
# ..          ...          ...          ...             ...             ...
# 95            4            2            2               4               1
# 96            3            3            2               2               1
# 97            1            1            4               4               3
# 98            2            4            3               3               3
# 99            1            1            3               2               1
#
#     Week3_Mobility  Week2_Mobility  Days_passed  Duration
# 0                4               3          161        63
# 1                3               3          119        21
# 2                4               1          350        28
# 3                2               3          105        49
# 4                2               2          182       105
# ..             ...             ...          ...       ...
# 95               4               2           91        42
# 96               2               2           77       105
# 97               2               4           49         7
# 98               4               2          406        63
# 99               3               4          378       126
#
# [100 rows x 9 columns]

# %%
from lore_sa.bbox import sklearn_classifier_bbox

# %%
bbox = sklearn_classifier_bbox.sklearnBBox(clf)

# %%
neighbour.df['Class_label'] = bbox.predict(neighbour.df)
neighbour.set_class_name('Class_label')
# Out:
# /opt/anaconda3/envs/xai/lib/python3.8/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
le=LabelEncoder()
neighbour.df['Class_label'] = le.fit_transform(neighbour.df['Class_label']) 
neighbour.df['Class_label']
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: Class_label, Length: 100, dtype: int64

# %%
neighbour.df
# Out:
#     Week5_Covid  Week4_Covid  Week3_Covid  Week5_Mobility  Week4_Mobility  \
# 0             2            1            3               4               2
# 1             3            4            4               3               2
# 2             3            1            1               3               4
# 3             4            3            1               1               4
# 4             1            2            4               3               2
# ..          ...          ...          ...             ...             ...
# 95            4            2            2               4               1
# 96            3            3            2               2               1
# 97            1            1            4               4               3
# 98            2            4            3               3               3
# 99            1            1            3               2               1
#
#     Week3_Mobility  Week2_Mobility  Days_passed  Duration  Class_label
# 0                4               3          161        63            1
# 1                3               3          119        21            1
# 2                4               1          350        28            1
# 3                2               3          105        49            1
# 4                2               2          182       105            1
# ..             ...             ...          ...       ...          ...
# 95               4               2           91        42            1
# 96               2               2           77       105            1
# 97               2               4           49         7            1
# 98               4               2          406        63            1
# 99               3               4          378       126            1
#
# [100 rows x 10 columns]

# %%
features = [c for c in neighbour.df.columns if c != neighbour.class_name]

# %%
surrogate = DecisionTreeSurrogate()
surrogate.train(neighbour.df[features].values , neighbour.df['Class_label'] )
# Out:
# DecisionTreeClassifier()

# %%
decoded_n = enc.inverse_transform(neighbour.df.iloc[:, :7])

# %%
from lore_sa.encoder_decoder import EncDec
class IdentityEncoder(EncDec):
    """
    It provides an interface to access Identity encoding functions.
    """
    def __init__(self,dataset_descriptor):
        super().__init__(dataset_descriptor)

    def encode(self, x: np.array) -> np.array:
        """
        It applies the encoder to the input features

        :param [Numpy array] x: Array to encode
        :return [Numpy array]: Encoded array
        """
        return x

    def get_encoded_features(self):
        """
        Provides a dictionary with the new encoded features name and the new index
        :return:
        """
        return self.encoded_features

    def decode(self, x: np.array) -> np.array:
        return x

    def decode_target_class(self, x: np.array):
        return x

# %%
result_df.columns
# Out:
# Index(['Class_label', 'Week5_Covid', 'Week4_Covid', 'Week3_Covid',
#        'Week5_Mobility', 'Week4_Mobility', 'Week3_Mobility', 'Week2_Mobility',
#        'Days_passed', 'Duration'],
#       dtype='object')

# %%
enc_result_df = generator_preprocessor.fit_transform(result_df)
enc_result_df=pd.DataFrame(enc_result_df, columns=result_df.columns)

# %%
enc_dataset = TabularDataset(enc_result_df, class_name="Class_label")

# %%
enc_dataset.descriptor
# Out:
# {'numeric': {},
#  'categorical': {'Week5_Covid': {'index': 0,
#    'distinct_values': [4.0, 1.0, 3.0, 2.0],
#    'count': {4.0: 133, 1.0: 100, 3.0: 166, 2.0: 69}},
#   'Week4_Covid': {'index': 1,
#    'distinct_values': [3.0, 4.0, 1.0, 2.0],
#    'count': {3.0: 173, 4.0: 127, 1.0: 81, 2.0: 87}},
#   'Week3_Covid': {'index': 2,
#    'distinct_values': [1.0, 4.0, 3.0, 2.0],
#    'count': {1.0: 54, 4.0: 115, 3.0: 215, 2.0: 84}},
#   'Week5_Mobility': {'index': 3,
#    'distinct_values': [1.0, 3.0, 4.0, 2.0],
#    'count': {1.0: 66, 3.0: 214, 4.0: 111, 2.0: 77}},
#   'Week4_Mobility': {'index': 4,
#    'distinct_values': [1.0, 3.0, 4.0, 2.0],
#    'count': {1.0: 81, 3.0: 205, 4.0: 109, 2.0: 73}},
#   'Week3_Mobility': {'index': 5,
#    'distinct_values': [1.0, 3.0, 2.0, 4.0],
#    'count': {1.0: 97, 3.0: 212, 2.0: 72, 4.0: 87}},
#   'Week2_Mobility': {'index': 6,
#    'distinct_values': ['c1', 'c2', 'c3', 'c4'],
#    'count': {'c1': 54, 'c2': 127, 'c3': 182, 'c4': 105}},
#   'Days_passed': {'index': 7,
#    'distinct_values': [63.0,
#     56.0,
#     147.0,
#     42.0,
#     161.0,
#     196.0,
#     280.0,
#     357.0,
#     434.0,
#     175.0,
#     238.0,
#     329.0,
#     406.0,
#     70.0,
#     392.0,
#     364.0,
#     273.0,
#     350.0,
#     245.0,
#     301.0,
#     49.0,
#     154.0,
#     371.0,
#     182.0,
#     252.0,
#     322.0,
#     168.0,
#     294.0,
#     441.0,
#     413.0,
#     315.0,
#     399.0,
#     189.0,
#     308.0,
#     105.0,
#     133.0,
#     231.0,
#     77.0,
#     203.0,
#     427.0,
#     266.0,
#     112.0,
#     224.0,
#     378.0,
#     287.0,
#     210.0,
#     140.0,
#     420.0,
#     119.0,
#     385.0,
#     343.0,
#     84.0,
#     126.0,
#     259.0,
#     217.0,
#     91.0,
#     98.0],
#    'count': {63.0: 19,
#     56.0: 14,
#     147.0: 10,
#     42.0: 16,
#     161.0: 15,
#     196.0: 5,
#     280.0: 17,
#     357.0: 30,
#     434.0: 6,
#     175.0: 16,
#     238.0: 3,
#     329.0: 7,
#     406.0: 9,
#     70.0: 10,
#     392.0: 11,
#     364.0: 15,
#     273.0: 17,
#     350.0: 8,
#     245.0: 10,
#     301.0: 6,
#     49.0: 17,
#     154.0: 8,
#     371.0: 7,
#     182.0: 13,
#     252.0: 3,
#     322.0: 20,
#     168.0: 16,
#     294.0: 5,
#     441.0: 10,
#     413.0: 6,
#     315.0: 9,
#     399.0: 6,
#     189.0: 10,
#     308.0: 4,
#     105.0: 1,
#     133.0: 2,
#     231.0: 13,
#     77.0: 10,
#     203.0: 7,
#     427.0: 2,
#     266.0: 3,
#     112.0: 3,
#     224.0: 5,
#     378.0: 9,
#     287.0: 5,
#     210.0: 5,
#     140.0: 9,
#     420.0: 1,
#     119.0: 3,
#     385.0: 1,
#     343.0: 2,
#     84.0: 3,
#     126.0: 2,
#     259.0: 1,
#     217.0: 1,
#     91.0: 1,
#     98.0: 1}},
#   'Duration': {'index': 8,
#    'distinct_values': [84,
#     7,
#     14,
#     42,
#     49,
#     21,
#     28,
#     91,
#     70,
#     105,
#     77,
#     63,
#     56,
#     98,
#     112,
#     35,
#     119,
#     147,
#     133,
#     126],
#    'count': {84: 11,
#     7: 30,
#     14: 78,
#     42: 57,
#     49: 34,
#     21: 56,
#     28: 58,
#     91: 18,
#     70: 9,
#     105: 5,
#     77: 16,
#     63: 15,
#     56: 24,
#     98: 6,
#     112: 5,
#     35: 40,
#     119: 2,
#     147: 1,
#     133: 2,
#     126: 1}}},
#  'target': {'Class_label': {'index': 9,
#    'distinct_values': [4.0, 1.0, 2.0, 3.0],
#    'count': {4.0: 123, 1.0: 118, 2.0: 59, 3.0: 168}}}}

# %%
x = decoded_n[5]
x1=neighbour.df[features].iloc[5].values
rule = surrogate.get_rule(x1, neighbour, IdentityEncoder(enc_dataset.descriptor))
print(rule)
# Out:
# rule.variable: Days_passed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 3
#       1 x = decoded_n[5]
#       2 x1=neighbour.df[features].iloc[5].values
# ----> 3 rule = surrogate.get_rule(x1, neighbour, IdentityEncoder(enc_dataset.descriptor))
#       4 print(rule)
#
# File ~/xai-visualization_rules_fi/notebooks/bonn_project/lore_sa/surrogate/decision_tree.py:155, in DecisionTreeSurrogate.get_rule(self, x, dataset, encoder)
#     152         premises.append(Expression(attribute, op, thr))
#     154 premises = self.compact_premises(premises)
# --> 155 return Rule(premises=premises, consequences=consequence, encoder=encoder)
#
# File ~/xai-visualization_rules_fi/notebooks/bonn_project/lore_sa/rule.py:63, in Rule.__init__(self, premises, consequences, encoder)
#      57 """
#      58 :param [list] premises: list of Expression objects representing the premises
#      59 :param [Expression] consequences: Expression representing the consequence
#      60 :param [EncDec] encoder: encoder to decode categorical rules
#      61 """
#      62 self.encoder = encoder
# ---> 63 self.premises = [self.decode_rule(p) for p in premises]
#      64 self.consequences = self.decode_rule(consequences)
#
# File ~/xai-visualization_rules_fi/notebooks/bonn_project/lore_sa/rule.py:63, in <listcomp>(.0)
#      57 """
#      58 :param [list] premises: list of Expression objects representing the premises
#      59 :param [Expression] consequences: Expression representing the consequence
#      60 :param [EncDec] encoder: encoder to decode categorical rules
#      61 """
#      62 self.encoder = encoder
# ---> 63 self.premises = [self.decode_rule(p) for p in premises]
#      64 self.consequences = self.decode_rule(consequences)
#
# File ~/xai-visualization_rules_fi/notebooks/bonn_project/lore_sa/rule.py:93, in Rule.decode_rule(self, rule)
#      91 if rule.variable.split('=')[0] in self.encoder.dataset_descriptor['categorical'].keys():
#      92     decoded_label = rule.variable.split("=")[0]
# ---> 93     decoded_value = rule.variable.split("=")[1]
#      94     rule.variable = decoded_label
#      95     rule.value = decoded_value
#
# IndexError: list index out of range

# %%
neighbour_df_5.to_csv('../../datasets/neighbourhood_95.csv', index=False)
